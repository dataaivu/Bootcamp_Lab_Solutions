# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#some extra useful libraries
import pandas as pd
import json
import pprint

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id="882be648225942f0b65f9d3f88231cd0",
    client_secret="47a9a235c1694ddc82dfa750495d2c9e"))

# %%
#read a playlist 

tracks_from_playlist = sp.playlist_tracks("https://open.spotify.com/playlist/4rnleEAOdmFAbRcNCgZMpY")

# %%
# this is the link to the "next" page
next_page_link = tracks_from_playlist["next"]
next_page_link
# Out:
# 'https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=100&limit=100&additional_types=track'

# %%
# this gives the full results directly
next_results = sp.next(tracks_from_playlist)
next_results
# Out:
# : 'https://api.spotify.com/v1/artists/3BmGtnKgCSGYIUhmivXKWX',
#        'id': '3BmGtnKgCSGYIUhmivXKWX',
#        'name': 'Kelly Clarkson',
#        'type': 'artist',
#        'uri': 'spotify:artist:3BmGtnKgCSGYIUhmivXKWX'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3xkK5tqB1kP84ZzWPnJ1x3'},
#      'href': 'https://api.spotify.com/v1/albums/3xkK5tqB1kP84ZzWPnJ1x3',
#      'id': '3xkK5tqB1kP84ZzWPnJ1x3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731573829abee986ce991c3e26',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021573829abee986ce991c3e26',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511573829abee986ce991c3e26',
#        'width': 64}],
#      'name': 'Breakaway',
#      'release_date': '2004',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
# ...

# %%
# Getting tracks

def get_tracks_ids_from_playlist(playlist_id):
    
    final_results = []
    result = sp.playlist_tracks(playlist_id)
    final_results.extend(result["items"])
    
    while result["next"]:
        
        result = sp.next(result)
        final_results.extend(result["items"])
        
    ids = [track["track"]["id"] for track in final_results]
    
    # we return only values that are not None:
    return [i for i in ids if i]

# %%
get_tracks_ids_from_playlist("https://open.spotify.com/playlist/4rnleEAOdmFAbRcNCgZMpY")
# Out:
# SXZqhjuNxLem',
#  '0S4RKPbRDA72tvKwVdXQqe',
#  '0PRqWiyOFMHVee81mr1bp6',
#  '4xTIknzHtjrqRQ1hlL2T8W',
#  '0azC730Exh71aQlOt9Zj3y',
#  '0qOnSQQF0yzuPWsXrQ9paz',
#  '2EBCVPNAG46nbgs6jXPGvv',
#  '6mnjcTmK8TewHfyOp3fC9C',
#  '6lV2MSQmRIkycDScNtrBXO',
#  '7uolkTLavH97itenLjNmx9',
#  '2tftivjRsvKs0jFH9h3Ti8',
#  '2Oehrcv4Kov0SuIgWyQY9e',
#  '4E5P1XyAFtrjpiIxkydly4',
#  '1NpW5kyvO4XrNJ3rnfcNy3',
#  '1XGmzt0PVuFgQYYnV2It7A',
#  '1fidCEsYlaVE3pHwKCvpFZ',
#  '4QNpBfC0zvjKqPJcyqBy9W',
#  '6YUTL4dYpB9xZO5qExPf05',
#  '6nYoTBmGFNgfTyRC8x1Fvp',
#  '2LEF1A8DOZ9wRYikWgVlZ8',
#  '6cpk00i5TxCqSeqNi2HuIe',
#  '4rHZZAmHpZrA3iH5zx8frV',
#  '0BiGd2FNDQ0eh79ZHfp6tS',
#  '7KxhSJOYiqCDclXDBNlFSZ',
#  '0YSJCrlSWF3meRTNCu54WI',
#  '3GpbwCm3YxiWDvy29Uo3vP',
#  '1VMW5hTQQ0C0pt19cc6Vi7',
#  '25ExfwA81qF88DbaUrVs4k',
#  '6OaYLWpreRh9EoLYwrS75P',
#  '5cCAZS9VhLGEDV4NCfieeg',
#  '7Dyq1bhhjknLKEGg4k5NLr',
#  '6T689Jvh5KrSXyaPtUWZtQ',
#  '0awvRwer2ByXjyDSON60Q3',
#  '0AH6WMe3OlAlUb5miXt2FQ',
# ...

# %%
#Getting features

def get_audio_features_df(playlist_id):
    track_ids = get_tracks_ids_from_playlist(playlist_id)
    aud_feat = [sp.audio_features(track)[0] for track in track_ids]
    return pd.DataFrame(aud_feat)

# %%
audio_f = get_audio_features_df("https://open.spotify.com/playlist/4rnleEAOdmFAbRcNCgZMpY")
audio_f.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.566   0.664    4    -5.303     0       0.0464        0.6340
# 1         0.768   0.820    7    -4.630     0       0.0475        0.1790
# 2         0.558   0.559    6    -9.222     1       0.0959        0.3710
# 3         0.679   0.715    9    -6.383     1       0.0407        0.0755
# 4         0.778   0.824   10    -5.892     0       0.0712        0.2840
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000     0.116    0.437  128.945  audio_features
# 1          0.000000     0.704    0.625  129.969  audio_features
# 2          0.000007     0.109    0.620   78.558  audio_features
# 3          0.000000     0.271    0.571  127.435  audio_features
# 4          0.000000     0.405    0.756  100.024  audio_features
#
#                        id                                   uri  \
# 0  7dS5EaCoMnN7DzlpT6aRn2  spotify:track:7dS5EaCoMnN7DzlpT6aRn2
# ...

# %%
audio_f.shape
# Out:
# (4896, 18)

# %%
()

# %%
df.shape
# Out:
# (100, 18)

# %%
#check its working - first track 
playlist["items"][0]["tracks"]["uri"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-aef89bbfac36> in <module>
#       1 #check its working - first track
# ----> 2 playlist["items"][0]["tracks"]["uri"]
#
# KeyError: 'items'
